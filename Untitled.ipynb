# %%
from scipy.stats import norm

# %%
norm_height = norm(x, 6)

# %%
p = norm_height.rvs(10)
p
# Out:
# array([168.36043679, 184.67118792, 166.59729168, 178.3471616 ,
#        181.04156468, 172.68231771, 175.86420989, 170.14513705,
#        171.4240209 , 162.69097229])

# %%
x = np.arange(160, 200, 0.05)
x
# Out:
# array([160.  , 160.05, 160.1 , 160.15, 160.2 , 160.25, 160.3 , 160.35,
#        160.4 , 160.45, 160.5 , 160.55, 160.6 , 160.65, 160.7 , 160.75,
#        160.8 , 160.85, 160.9 , 160.95, 161.  , 161.05, 161.1 , 161.15,
#        161.2 , 161.25, 161.3 , 161.35, 161.4 , 161.45, 161.5 , 161.55,
#        161.6 , 161.65, 161.7 , 161.75, 161.8 , 161.85, 161.9 , 161.95,
#        162.  , 162.05, 162.1 , 162.15, 162.2 , 162.25, 162.3 , 162.35,
#        162.4 , 162.45, 162.5 , 162.55, 162.6 , 162.65, 162.7 , 162.75,
#        162.8 , 162.85, 162.9 , 162.95, 163.  , 163.05, 163.1 , 163.15,
#        163.2 , 163.25, 163.3 , 163.35, 163.4 , 163.45, 163.5 , 163.55,
#        163.6 , 163.65, 163.7 , 163.75, 163.8 , 163.85, 163.9 , 163.95,
#        164.  , 164.05, 164.1 , 164.15, 164.2 , 164.25, 164.3 , 164.35,
#        164.4 , 164.45, 164.5 , 164.55, 164.6 , 164.65, 164.7 , 164.75,
#        164.8 , 164.85, 164.9 , 164.95, 165.  , 165.05, 165.1 , 165.15,
# ...

# %%
norm_height_x = norm(177, 6)

# %%
pdfs = norm_height_x.pdf(p)
np.product(pdfs)
# Out:
# 6.822805718751472e-16

# %%
np.product(pdfs)
# Out:
# 5.1407956169373685e-15

# %%
norm_height_noelani = norm(75, 3)

# %%
pdfs_noelani = norm_height_noelani.pdf(p)
pdfs_noelani
# Out:
# array([6.67759539e-212, 8.39706217e-292, 4.92906938e-204, 2.67334944e-259,
#        6.52944435e-273, 8.00635442e-232, 4.57948860e-247, 5.09932542e-220,
#        6.25763340e-226, 3.89595257e-187])

# %%
np.product(pdfs_noelani)
# Out:
# 0.0
