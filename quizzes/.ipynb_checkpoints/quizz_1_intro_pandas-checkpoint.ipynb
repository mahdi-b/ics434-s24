# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1. To load the dataset shown in the image below, which command is appropriate? The dataset is named `spending.csv` and is located in the current directory. Additionally, the column order in `spending.csv` matches the order presented in the image.
#
#
# ![image.png](attachment:6d79e1bc-aefd-4a5e-906e-f451f214abb4.png)
#
# ```python
# 1- pd.read_csv("spending.csv", index_col="unique_id")
# 2- pd.read_csv("spending.csv", columns="unique_id")
# 3- pd.read_csv("spending.csv")
# 4- pd.read_csv("spending.csv", ncols=3, usecols=["unique_id", "specialty"])
# ```

# %% [markdown]
# #### 2. Assuming the data was saved to `spending_df`, which of the following solutions **are** valid ways  select the column medications from the dataframe above?
#
# ```python
# 1- spending_df.iloc[:, 3]
# 2- spending_df.loc[:, "nb_beneficiaries"]
# 3- spending_df["nb_beneficiaries"]
# 4- all of the above
# ```

# %%
spending_df
# Out:
#             doctor_id                  specialty  \
# unique_id
# BK982218   1750389599          INTERNAL MEDICINE
# CG916968   1952344418                 CARDIOLOGY
# SA964720   1669522744          INTERNAL MEDICINE
# TR390895   1639597115                        NaN
# JA436080   1073781571                        NaN
# WO822855   1689080749  INTERVENTIONAL CARDIOLOGY
# PC409862   1568483196          INTERNAL MEDICINE
# CG865025   1497955603                 CARDIOLOGY
# XI271888   1982785085          INTERNAL MEDICINE
# EQ932492   1336217306          INTERNAL MEDICINE
# DT789371   1518992585                        NaN
# IC286267   1194718841          INTERNAL MEDICINE
# PK692876   1144227802          INTERNAL MEDICINE
# AX468217   1518959154              OPHTHALMOLOGY
# SU660670   1366528028          INTERNAL MEDICINE
# UP346469   1457338337         NURSE PRACTITIONER
# DA943932   1659338887            PAIN MANAGEMENT
# ZP892365   1336172261  INTERVENTIONAL CARDIOLOGY
# TU901486   1326036062            FAMILY PRACTICE
# US339660   1548250772                 PSYCHIATRY
# JX313970   1003828724            FAMILY PRACTICE
# SU398849   1437124419          INTERNAL MEDICINE
# BU202944   1538156542            FAMILY PRACTICE
# RH274400   1023342144         NURSE PRACTITIONER
# ON964391   1528031978          INTERNAL MEDICINE
# CQ964168   1174510481      OBSTETRICS/GYNECOLOGY
# AL166376   1255498127                 PSYCHIATRY
# GD287242   1487714606            FAMILY PRACTICE
# BT820276   1477976512        PHYSICIAN ASSISTANT
# AD891213   1326351156          INTERNAL MEDICINE
# VY752576   1932169778  INTERVENTIONAL CARDIOLOGY
# GF883895   1891734083  INTERVENTIONAL CARDIOLOGY
# MK361461   1245206184                 CARDIOLOGY
# CF887728   1225012420                        NaN
# FE564384   1225180961            FAMILY PRACTICE
# UB518915   1487602389            FAMILY PRACTICE
# UM165381   1972629749            FAMILY PRACTICE
# YS123432   1841589744                 CARDIOLOGY
# DJ966828   1629022389         NURSE PRACTITIONER
# VZ416961   1831119486            FAMILY PRACTICE
# FV632964   1104832492              ENDOCRINOLOGY
# AU352153   1386868529         ORTHOPEDIC SURGERY
# PM639115   1760643803          PULMONARY DISEASE
# OB710833   1699921866            FAMILY PRACTICE
# NH872050   1851666473          INTERNAL MEDICINE
# MG439448   1962498311              OPHTHALMOLOGY
# WO875842   1548267172            FAMILY PRACTICE
# YN526335   1982913554                        NaN
# ES437458   1639267875                        NaN
# NM108377   1326026154        HEMATOLOGY/ONCOLOGY
# YG219581   1104853860            FAMILY PRACTICE
# QK186918   1225021678          INTERNAL MEDICINE
# OR161686   1801892781            FAMILY PRACTICE
# XT297229   1841215423            FAMILY PRACTICE
#
#                                medication  nb_beneficiaries   spending  \
# unique_id
# BK982218                     AZITHROMYCIN              12.0     $77.26
# CG916968                      SIMVASTATIN              85.0    $767.83
# SA964720                  INSULIN DETEMIR              14.0   $5409.29
# TR390895               LOSARTAN POTASSIUM              11.0     $65.62
# JA436080                      LAMOTRIGINE              12.0    $8873.7
# WO822855                   SERTRALINE HCL              26.0        NaN
# PC409862   CLOTRIMAZOLE/BETAMETHASONE DIP              12.0    $310.97
# CG865025             ATORVASTATIN CALCIUM              82.0   $2726.72
# XI271888   BUDESONIDE/FORMOTEROL FUMARATE              37.0  $10253.35
# EQ932492                    OXYCODONE HCL               NaN    $355.43
# DT789371     FENOFIBRATE NANOCRYSTALLIZED              33.0   $2565.44
# IC286267                    METFORMIN HCL              53.0    $340.75
# PK692876                       LOVASTATIN              34.0    $349.58
# AX468217                CIPROFLOXACIN HCL              17.0   $2791.18
# SU660670                       LISINOPRIL              25.0    $118.89
# UP346469             ROSUVASTATIN CALCIUM              13.0   $2837.07
# DA943932                    OXYCODONE HCL              52.0  $15272.18
# ZP892365              LIOTHYRONINE SODIUM              11.0    $440.79
# TU901486           ZOSTER VACCINE LIVE/PF              16.0   $3078.49
# US339660                    BUSPIRONE HCL             126.0   $2239.34
# JX313970                      RISPERIDONE             220.0   $8045.03
# SU398849                          DIGOXIN              15.0    $618.52
# BU202944                ALBUTEROL SULFATE              16.0   $1456.08
# RH274400                DICLOFENAC SODIUM              32.0   $1491.24
# ON964391                         FENTANYL               NaN   $1730.84
# CQ964168                NYSTATIN/TRIAMCIN              11.0   $1219.38
# AL166376          CITALOPRAM HYDROBROMIDE              11.0      $89.3
# GD287242            ESTROGENS, CONJUGATED              21.0   $5846.93
# BT820276                      LAMOTRIGINE               NaN    $327.12
# AD891213                              NaN               NaN        NaN
# VY752576                       OMEPRAZOLE             107.0   $2052.04
# GF883895             ATORVASTATIN CALCIUM             204.0   $2547.07
# MK361461              PANTOPRAZOLE SODIUM             102.0   $1608.42
# CF887728           FLUTICASONE PROPIONATE              39.0   $8934.45
# FE564384                      LIRAGLUTIDE              33.0  $15640.59
# UB518915                       LISINOPRIL             450.0   $3147.16
# UM165381             ESCITALOPRAM OXALATE              36.0    $501.79
# YS123432                  VENLAFAXINE HCL              25.0    $265.49
# DJ966828                        EZETIMIBE              20.0  $10869.06
# VZ416961                    DILTIAZEM HCL              13.0    $218.56
# FV632964   INSULIN GLARGINE,HUM.REC.ANLOG             105.0  $76346.72
# AU352153       ACETAMINOPHEN WITH CODEINE              62.0    $401.89
# PM639115                       OMEPRAZOLE              33.0    $814.71
# OB710833    SULFAMETHOXAZOLE/TRIMETHOPRIM              20.0     $74.37
# NH872050                    METFORMIN HCL              43.0    $525.54
# MG439448                  PILOCARPINE HCL              20.0   $1910.22
# WO875842                      AMOXICILLIN              36.0    $180.08
# YN526335                       ALPRAZOLAM              96.0    $615.66
# ES437458        HYDROCODONE/ACETAMINOPHEN              62.0        NaN
# NM108377             LIDOCAINE/PRILOCAINE              13.0        NaN
# YG219581                        VALSARTAN              21.0   $4341.38
# QK186918   INSULIN GLARGINE,HUM.REC.ANLOG             196.0  $79045.15
# OR161686               MONTELUKAST SODIUM              36.0    $361.43
# XT297229    IPRATROPIUM/ALBUTEROL SULFATE              11.0    $248.95
#
#            spending_float
# unique_id
# BK982218            77.26
# CG916968           767.83
# SA964720          5409.29
# TR390895            65.62
# JA436080          8873.70
# WO822855              NaN
# PC409862           310.97
# CG865025          2726.72
# XI271888         10253.35
# EQ932492           355.43
# DT789371          2565.44
# IC286267           340.75
# PK692876           349.58
# AX468217          2791.18
# SU660670           118.89
# UP346469          2837.07
# DA943932         15272.18
# ZP892365           440.79
# TU901486          3078.49
# US339660          2239.34
# JX313970          8045.03
# SU398849           618.52
# BU202944          1456.08
# RH274400          1491.24
# ON964391          1730.84
# CQ964168          1219.38
# AL166376            89.30
# GD287242          5846.93
# BT820276           327.12
# AD891213              NaN
# VY752576          2052.04
# GF883895          2547.07
# MK361461          1608.42
# CF887728          8934.45
# FE564384         15640.59
# UB518915          3147.16
# UM165381           501.79
# YS123432           265.49
# DJ966828         10869.06
# VZ416961           218.56
# FV632964         76346.72
# AU352153           401.89
# PM639115           814.71
# OB710833            74.37
# NH872050           525.54
# MG439448          1910.22
# WO875842           180.08
# YN526335           615.66
# ES437458              NaN
# NM108377              NaN
# YG219581          4341.38
# QK186918         79045.15
# OR161686           361.43
# XT297229           248.95

# %% [markdown]
# #### 3. Assuming the data was saved to spending_df, which of the following solutions is a valid way select rows 0, 3, 7 and 21 from the dataframe above?
# ```python
# 1- spending_df[[0, 3, 7, 21]]
# 2- spending_df[[0, 3, 7, 21],:]
# 3- spending_df.iloc[[0, 3, 7, 21]]
# 4- spending_df.iloc[0, 3, 7, 21]
# ```

# %% [markdown]
# 4. Which method can be used to count the number of missing values (NaN) in each column as shown below?
#
# ```
# doctor_id           0
# specialty           6
# medication          1
# nb_beneficiaries    4
# spending            4
# spending_float      4
# dtype: int64
# ```
#
#
# ```python
# 1- spending_df.isna()
# 2- spending_df.isna().sum(axis=0)
# 3- spending_df.isna().sum(axis=1)
# 3- spending_df.isna().shape
# ```

# %% [markdown]
# #### 5. Assuming 'spending_df' is a DataFrame with columns including 'specialty' and 'spending', and 'nb_beneficiaries', the following code snippet is intended to normalize the 'spending' by 'nb_beneficiaries' (i.e., calculate 'spending' / 'nb_beneficiaries') specifically for entries where the 'specialty' is "INTERNAL MEDICINE". Given that 'spending_df' has a shape of (54, 6) and there are 13 entries with the specialty "INTERNAL MEDICINE" what does the following snippet return?
#
# ```python
# type(spending_df["spending_float"][internal_med_filter] / spending_df["nb_beneficiaries"])
# ```
#
# ```python
# 1- Error!
# 2- Series with a dimension of (54, 6)
# 3- Series with a dimension of (13, )
# 4- Series with a dimension of (1, 6)
# ```

# %% [markdown]
# #### 6. Which of the following code snippets can be used to __**filter out**__ instances where `specialty` is "INTERNAL MEDICINE" and `nb_beneficiaries` is greater than or equal to 12?
#
#
# ```python
# 1- spending_df[not (spending_df["specialty"] == "INTERNAL MEDICINE") and  (spending_df["nb_beneficiaries"] >= 12)]
# 1- spending_df[(spending_df["specialty"] == "INTERNAL MEDICINE") and  (spending_df["nb_beneficiaries"] >= 12)]
# 3- spending_df[~((spending_df["specialty"] == "INTERNAL MEDICINE") &  (spending_df["nb_beneficiaries"] >= 12))]
# 4- spending_df[(spending_df["specialty"] != "INTERNAL MEDICINE") &  (spending_df["nb_beneficiaries"] >= 12)]
# ```

# %% [markdown]
# ### 7. Which of the following snippets returns the number of rows where `nb_beneficiaries` is greater than 100?
#
# ```python
# 1- (spending_df['nb_beneficiaries'] > 100).sum()
# 2- spending_df['nb_beneficiaries'] > 100
# 3- spending_df[(spending_df['nb_beneficiaries'] > 100)].shape[0]
# 4- (spending_df['nb_beneficiaries'] > 100).shape[0]
# ```

# %% [markdown]
# ### 8. Consider the the two following DataFrames:
# ```python
# first_df  = pd.DataFrame({"A": [1, 2, 3, 4, 5]})
# second_df =  pd.DataFrame({"A": [1, 2, 3, 4, 5]}, index= [f"row_{i}" for i in range(5)])
# ```
#
# ![image.png](attachment:03926fcb-9bcb-45b1-a967-43f47ba87064.png)
#
#
# What does the following snippet return?
#
# ```python
# first_df["A"] + second_df["A"]).shape
# ```
#
# ```python
# 1- (10,)
# 2- (5,)
# 3- (5,2)
# 4- Error
# ```
