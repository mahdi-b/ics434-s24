# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Which of the following methods can be directly used to visually estimate the mean and get an idea about the variance (e.g., say whether it's small or large) of a probability distribution based on a set of 1,000 measurements?
#
# A. Maximum Likelihood Estimation
#
#
# B. Approximate Bayesian Computation
#
# C. Kernel Density Estimation   <--- CORRECT ANSWER
#
# D. Bootstrapping the samples and computing parameters of interest.

# %% [markdown]
# ### 2. You are computing the Maximum Likelihood (ML) of a dataset given a parameter and encounter the following error:
#
# ![image.png](attachment:image.png)
#
# How can you adjust the code to avoid this error?
#
# A. The error is due to the dataset containing too many data points. Taking a subsample of the data will fix it.
#
# B. The error is because the computing environment does not support a high enough precision for the probability calculations.
#
# C. Instead of computing the product of the values computed using probability density functions (PDFs), compute the sum of the log of the values. <--- CORRECT ANSWER
#
# D. We could potentially estimate a proxy of the ML as the sum of the log of the PDFs.

# %% [markdown]
# ### 3. You are interested in estimating the possible mean of a distribution. Which of the following methods can be used to return a confidence interval for the possible values that the mean could fall into?
#
#
# A. Maximum Likelihood Estimation
#
# B. Bootstrapping     <--- CORRECT ANSWER
#
# C. Kernel Density Estimation (KDE)
#
# D. Approximate Bayesian Method

# %% [markdown]
# ### 4. During a work presentation, a colleague mentioned that the mean of the distribution is between 3.25 and 3.96 with a 0.92 probability. What is the natural conclusion about the method used by the colleague?
#
# A. Maximum Likelihood Estimation
#
# B. Bootstrapping
#
# C. Kernel Density Estimation (KDE)
#
# D. Approximate Bayesian Method  <--- CORRECT ANSWER

# %% [markdown]
# ### 5. Which of the following statements are incorrect (FALSE)? Select all correct statements to obtain full credit.
#
# A. Given n samples, bootstrapping samples n values from the original data without replacement. <--- CORRECT ANSWER
#
# B. Given n samples, bootstrapping produces a new dataset that contains a good representation of extreme values (outliers) in the data.
#
# C. Given n samples, the standard deviation of the bootstrap samples is an unbiased estimate of the population standard deviation. <--- OK IF THIS IS INCLUDED EVEN THOUGH IT'S FALSE
#
# D. Given n samples, a bootstrap sample may contain observations that appear in the original sample only once but are duplicated in the bootstrap sample. <--- CORRECT ANSWER

# %% [markdown]
# ### 6. The orange and blue curves below represent KDE (Kernel Density Estimation) plots of the same data points. Why do they appear different?
#
# ![image.png](attachment:image.png)
#
# A. The values in the blue curve are normalized.
#
# B. The values in the orange curve were log-transformed (computed the log of the values).
#
# C. The two KDEs were computed using different kernel bandwidths. <--- CORRECT ANSWER
#
#
# D. KDE is a probabilistic process, and the two curves are different because of the randomness involved in the KDE generation.

# %% [markdown]
# ### 7. Challenge: If you are interested in estimating the maximum value of a very large sample, is bootstrapping a suitable approach?
#
# A. Yes
# B. No
#
# Explan your answer:

# %%
No, bootstrapping does not guarantee we will capture the maximum when we resample.
